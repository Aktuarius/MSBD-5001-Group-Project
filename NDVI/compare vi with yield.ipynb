# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %%
yield_df = pd.read_csv(r'C:\Users\talha\OneDrive - HKUST Connect\Semester Spring 2022\5001\Group Project\Project code\MSBD-5001-Group-Project\Yield_Data\yield.csv')

# %%
yield_df.head()
# Out:
#                   Country Name Country Code                 Indicator Name  \
# 0                        Aruba          ABW  Cereal yield (kg per hectare)
# 1  Africa Eastern and Southern          AFE  Cereal yield (kg per hectare)
# 2                  Afghanistan          AFG  Cereal yield (kg per hectare)
# 3   Africa Western and Central          AFW  Cereal yield (kg per hectare)
# 4                       Angola          AGO  Cereal yield (kg per hectare)
#
#    Indicator Code  1960         1961         1962        1963         1964  \
# 0  AG.YLD.CREL.KG   NaN          NaN          NaN         NaN          NaN
# 1  AG.YLD.CREL.KG   NaN   924.994622   941.783828  938.845615   887.762617
# 2  AG.YLD.CREL.KG   NaN  1115.100000  1079.000000  985.800000  1082.800000
# 3  AG.YLD.CREL.KG   NaN   675.354815   702.244456  698.032526   691.134187
# 4  AG.YLD.CREL.KG   NaN   828.000000   830.300000  798.400000   875.800000
#
# ...

# %%
# test for Ethiopia
ndvi_et = pd.read_csv(r'C:\Users\talha\OneDrive - HKUST Connect\Semester Spring 2022\5001\Group Project\Project code\MSBD-5001-Group-Project\NDVI\Ethiopia\NDVI_2000-01-01_2022-01-01.csv', index_col=[0])

# %%
evi_et = pd.read_csv(r'C:\Users\talha\OneDrive - HKUST Connect\Semester Spring 2022\5001\Group Project\Project code\MSBD-5001-Group-Project\NDVI\Ethiopia\EVI_2000-01-01_2022-01-01.csv', index_col=[0])

# %%
# ndvi_et

# %%
# evi = evi.drop([0])

# %%
# ndvi = ndvi.drop([0])

# %%
# evi_et

# %%
# test for Kenya
ndvi_ke = pd.read_csv(r'C:\Users\talha\OneDrive - HKUST Connect\Semester Spring 2022\5001\Group Project\Project code\MSBD-5001-Group-Project\NDVI\Kenya\NDVI_2000-01-01_2022-01-01.csv', index_col=[0])

# %%
# test for Kenya
evi_ke = pd.read_csv(r'C:\Users\talha\OneDrive - HKUST Connect\Semester Spring 2022\5001\Group Project\Project code\MSBD-5001-Group-Project\NDVI\Kenya\EVI_2000-01-01_2022-01-01.csv', index_col=[0])

# %%
# ndvi_ke

# %%
label_et = yield_df.loc[yield_df['Country Name'] == 'Ethiopia']

# %%
label_ke = yield_df.loc[yield_df['Country Name'] == 'Kenya']

# %%
# label_et

# %%
label_et = label_et.drop(['Country Name','Country Code','Indicator Name', 'Indicator Code'],axis=1)

# %%
label_ke = label_ke.drop(['Country Name','Country Code','Indicator Name', 'Indicator Code'],axis=1)

# %%
# label_et

# %%
label_et_T = label_et.T

# %%
label_ke_T = label_ke.T

# %%
label_et_T = label_et_T.dropna()

# %%
label_ke_T = label_ke.T.dropna()

# %%
# label_et_T

# %%
label_et_2010to2018 = label_et_T.loc['2000':'2018',:]

# %%
label_ke_2010to2018 = label_ke_T.loc['2000':'2018',:]

# %%
# label_2010to2018

# %%
label_et_2010to2018.rename(columns={72:'Yield'}, inplace=True)
# Out:
# C:\Users\talha\AppData\Local\Temp\ipykernel_162164\1206818130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_et_2010to2018.rename(columns={72:'Yield'}, inplace=True)

# %%
label_ke_2010to2018.rename(columns={72:'Yield'}, inplace=True)
# Out:
# C:\Users\talha\AppData\Local\Temp\ipykernel_162164\123332669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_ke_2010to2018.rename(columns={72:'Yield'}, inplace=True)

# %%
# label_et_2010to2018

# %%
# label_ke_2010to2018

# %% [markdown]
# ### Comparison of Yield

# %%
# yield comparison

time = label_ke_2010to2018.index
y1 = label_ke_2010to2018.iloc[:,0]
# y2 = ndvi.iloc[:,0]
y2 = label_et_2010to2018.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(500, 3500, 500))
ax2.set_yticks(np.arange(500, 3500, 500))

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Comparison of EVI

# %%
time = evi_ke.index
y1 = evi_ke.iloc[:,0]
y2 = evi_et.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('EVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('EVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.1, 0.5, 0.1))
ax2.set_yticks(np.arange(0.1, 0.5, 0.1))

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Comparison of NDVI

# %%
time = ndvi_ke.index
y1 = ndvi_ke.iloc[:,0]
y2 = ndvi_et.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('NDVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('NDVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.2, 0.8, 0.1))
ax2.set_yticks(np.arange(0.2, 0.8, 0.1))

fig.tight_layout()
plt.show()

# %% [markdown]
# # Compare using max annual NDVI and max annual EVI
# From the graphs above it is difficult to see any relation between the vegetation indices and the yield of corresponding country. In 'Deep Learning For Crop Yield Prediction in Africa' a simple baseline regression model using highest average NDVI was used. Plots of highest NDVI and EVI are plotted below to observe any correlations

# %%
evi_ke.index = pd.to_datetime(evi_ke.index)

# %%
type(evi_ke.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# evi_ke

# %%
ndvi_ke.index = pd.to_datetime(ndvi_ke.index)

# %%
evi_et.index = pd.to_datetime(evi_et.index)

# %%
ndvi_et.index = pd.to_datetime(ndvi_et.index)

# %%
kenya_evi_annual = evi_ke.groupby(pd.Grouper(freq="Y")).mean()
kenya_ndvi_annual = ndvi_ke.groupby(pd.Grouper(freq="Y")).mean()

# %%
# kenya_evi_annual

# %%
ethiopia_evi_annual = evi_et.groupby(pd.Grouper(freq="Y")).mean()
ethiopia_ndvi_annual = ndvi_et.groupby(pd.Grouper(freq="Y")).mean()

# %%
# ethiopia_evi_annual

# %% [markdown]
# ### Comparison using Average Annual Values

# %%
time = ethiopia_evi_annual.index
y1 = kenya_evi_annual.iloc[:,0]
y2 = ethiopia_evi_annual.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('EVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('EVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.1, 0.5, 0.1))
ax2.set_yticks(np.arange(0.1, 0.5, 0.1))

fig.tight_layout()
plt.show()

# %%
time = ethiopia_ndvi_annual.index
y1 = kenya_ndvi_annual.iloc[:,0]
y2 = ethiopia_ndvi_annual.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('NDVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('NDVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.2, 0.6, 0.1))
ax2.set_yticks(np.arange(0.2, 0.6, 0.1))

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Comparison using Max Annual values

# %%
kenya_evi_annual_max = evi_ke.groupby(pd.Grouper(freq="Y")).max()
kenya_ndvi_annual_max = ndvi_ke.groupby(pd.Grouper(freq="Y")).max()

# %%
ethiopia_evi_annual_max = evi_et.groupby(pd.Grouper(freq="Y")).max()
ethiopia_ndvi_annual_max = ndvi_et.groupby(pd.Grouper(freq="Y")).max()

# %%
time = ethiopia_ndvi_annual_max.index
y1 = kenya_ndvi_annual_max.iloc[:,0]
y2 = ethiopia_ndvi_annual_max.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('Max Annual NDVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Max Annual NDVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.2, 0.8, 0.1))
ax2.set_yticks(np.arange(0.2, 0.8, 0.1))

fig.tight_layout()
plt.show()

# %%
# ethiopia_evi_annual_max

# %%
time = ethiopia_evi_annual_max.index
y1 = kenya_evi_annual_max.iloc[:,0]
y2 = ethiopia_evi_annual_max.iloc[:,0]

# plt.style.use('seaborn')

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time')
ax1.set_ylabel('Max Annual EVI Kenya',color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Max Annual EVI Ethiopia', color=color)
ax2.plot(time,y2,color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ax2 = ax1.twinx()
# color = 'tab:blue'
# ax2.set_ylabel('NDVI', color=color)
# ax2.plot(time,y2,color=color)
# ax2.tick_params(axis='y', labelcolor=color)

# ax1.set_xlabel('Time')
# ax1.set_ylabel('EVI')
# ax2.set_ylabel('NDVI')
# plt.legend()

ax1.set_yticks(np.arange(0.1, 0.6, 0.1))
ax2.set_yticks(np.arange(0.1, 0.6, 0.1))

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Note:
#     -if wanna use max values for regression:
#     -features for kenya = kenya_evi_annual_max and kenya_ndvi_annual_max
#     -label for kenya = label_ke_2010to2018
#     -features for ethipia = ethiopia_evi_annual_max and ethiopia_ndvi_annual_max
#     -label for ethiopia = label_et_2010to2018
#
#     -if wanna use average values for regression:
#     -features for kenya = kenya_evi_annual and kenya_ndvi_annual
#     -label for kenya = label_ke_2010to2018
#     -features for ethipia = ethiopia_evi_annual and ethiopia_ndvi_annual
#     -label for ethiopia = label_et_2010to2018

# %% [markdown]
# ### Tests
# Requied code ends here

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# time = np.array(evi.iloc[:,0])
# y1 = np.array(evi.iloc[:,1])
# y2 = np.array(ndvi.iloc[:,1])
# plt.plot(time, y1) # plot first line
# # plt.plot(time, y2) # plot second line
# plt.show()

# %%
time = label_2010to2018.index
y1 = label_2010to2018.iloc[:,0]
# y2 = np.array(ndvi.loc[:,"NDVI"])
plt.plot(time, y1) # plot first line
# plt.plot(time, y2) # plot second line
plt.show()

# %%
evi_part = evi_ke.iloc[1:10,:]

# %%
sns.lineplot(data=evi_part)
# Out:
# <AxesSubplot:>

# %%
label_t

# %%
sns.lineplot(data=label_2010to2018)
# Out:
# <AxesSubplot:>
