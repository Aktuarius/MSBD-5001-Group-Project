# %%
# Use PyTorch to build neural networkabs
# Inspired by pytorch workshop conducted in MSBD 5001 course

# Import required packages
import os
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
import cv2
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchvision.transforms import ToPILImage
from torch.nn.init import kaiming_uniform_
import matplotlib.pyplot as plt

# %%
# Import the yield data as pandas data frame (Note this is saved as a csv file in base working directory)
file_path = os.path.join(os.getcwd()) + '/'
file_name = 'Crop_Yields_PR.csv'
yield_data = pd.read_csv(file_path + file_name)

# %%
# hist_dir = os.path.join(self.hist_dir, self.filenames[idx])
# #hist = torch.from_numpy(np.load(hist_dir)).float()
# hist = np.load(hist_dir)

file_path = os.path.join(os.getcwd(), 'malawi')
files = os.listdir(file_path)

# %%
print(file_path)
print(files)
hist_dir = os.path.join(file_path, files[0])
# Out:
# C:\Users\Paul\GitHub\MSBD-5001-Group-Project\PR_Sandbox\malawi
# ['Malawi_2002.npy', 'Malawi_2003.npy', 'Malawi_2004.npy', 'Malawi_2005.npy', 'Malawi_2006.npy', 'Malawi_2007.npy', 'Malawi_2008.npy', 'Malawi_2009.npy', 'Malawi_2010.npy', 'Malawi_2011.npy', 'Malawi_2012.npy', 'Malawi_2013.npy', 'Malawi_2014.npy', 'Malawi_2015.npy']

# %%
print(hist_dir)
# Out:
# C:\Users\Paul\GitHub\MSBD-5001-Group-Project\PR_Sandbox\malawi\Malawi_2002.npy

# %%
hist = np.load(hist_dir)

# %%
hist.shape
# Out:
# (576, 46)

# %%
# Create class to load dataset

class CustomImageDataset():
    def __init__(self, hist_dir, crop_yield_table, transform=None, target_transform=None):  
        self.hist_dir = hist_dir # References the directory for each given country where the data is stored
        self.transform = transform
        self.target_transform = target_transform
        # load the files 
        filenames = [] # For every year, yields a numpy array of dimension 576 x 46
        crop_yields = []
        for filename in os.listdir(hist_dir):
            print(filename)
            filenames.append(filename)
            crop_yields.append(crop_yield_table[crop_yield_table.Year == int(filename[-8:-4])]['Cereal Yield'].values[0])
        self.filenames = filenames
        self.crop_yields =crop_yields
        
    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        hist_dir = os.path.join(self.hist_dir, self.filenames[idx])
        #hist = torch.from_numpy(np.load(hist_dir)).float()
        hist = np.load(hist_dir)
        # hist_3 = img2 = cv2.merge((hist,hist,hist))
        
        # Turn into 3 channel array (triplicate of single layer) --> to function with known model architectures
        hist_3 = np.zeros( ( np.array(hist).shape[0], np.array(hist).shape[1], 3 ) )
        hist_3[:,:,0] = hist # same value in each channel
        hist_3[:,:,1] = hist
        hist_3[:,:,2] = hist
        
        if self.transform:
            hist = self.transform(hist_3).float()
        crop_yield = torch.from_numpy(self.crop_yields[idx].reshape(-1, 1)).float()
        return hist, crop_yield

# %%
from torchvision.transforms import Resize, ToTensor, Compose

# crop_dataset = CustomImageDataset("./kenya", crop_yield_table = yield_data, transform = ToTensor())
crop_dataset = CustomImageDataset("./rwanda", crop_yield_table = yield_data, transform = Compose([ToTensor(), Resize((224,224))]))

# print(dataset.filenames)
# print(dataset.crop_yields)
# dataset[3]
# Out:
# Rwanda_2002.npy
# Rwanda_2003.npy
# Rwanda_2004.npy
# Rwanda_2005.npy
# Rwanda_2006.npy
# Rwanda_2007.npy
# Rwanda_2008.npy
# Rwanda_2009.npy
# Rwanda_2010.npy
# Rwanda_2011.npy
# Rwanda_2012.npy
# Rwanda_2013.npy
# Rwanda_2014.npy
# Rwanda_2015.npy

# %%
crop_dataset[3] # Shows for a given tensor which consists of a pair of 1) array of binned histogram data; and 2) yield output
# Out:
# (tensor([[[7.4830e-02, 7.4830e-02, 7.4544e-02,  ..., 3.4456e-02,
#            3.4742e-02, 3.4742e-02],
#           [1.7979e-01, 1.7979e-01, 1.8042e-01,  ..., 3.2211e-01,
#            3.2094e-01, 3.2094e-01],
#           [4.8591e-04, 4.8591e-04, 7.5923e-04,  ..., 1.0480e-02,
#            1.0447e-02, 1.0447e-02],
#           ...,
#           [6.3192e-01, 6.3192e-01, 6.3298e-01,  ..., 9.0366e-01,
#            9.0379e-01, 9.0379e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[7.4830e-02, 7.4830e-02, 7.4544e-02,  ..., 3.4456e-02,
#            3.4742e-02, 3.4742e-02],
#           [1.7979e-01, 1.7979e-01, 1.8042e-01,  ..., 3.2211e-01,
#            3.2094e-01, 3.2094e-01],
#           [4.8591e-04, 4.8591e-04, 7.5923e-04,  ..., 1.0480e-02,
#            1.0447e-02, 1.0447e-02],
#           ...,
#           [6.3192e-01, 6.3192e-01, 6.3298e-01,  ..., 9.0366e-01,
#            9.0379e-01, 9.0379e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[7.4830e-02, 7.4830e-02, 7.4544e-02,  ..., 3.4456e-02,
#            3.4742e-02, 3.4742e-02],
#           [1.7979e-01, 1.7979e-01, 1.8042e-01,  ..., 3.2211e-01,
#            3.2094e-01, 3.2094e-01],
#           [4.8591e-04, 4.8591e-04, 7.5923e-04,  ..., 1.0480e-02,
#            1.0447e-02, 1.0447e-02],
#           ...,
#           [6.3192e-01, 6.3192e-01, 6.3298e-01,  ..., 9.0366e-01,
#            9.0379e-01, 9.0379e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]),
#  tensor([[1183.6000]]))

# %%
crop_dataset[3][0].dtype
# Out:
# torch.float32

# %%
crop_dataset[3][1].dtype
# Out:
# torch.float32

# %%
crop_dataset[3][0].shape # For each binned histogram data, consists of 576 observations across 29 dimensions
# Out:
# torch.Size([3, 224, 224])

# %%
# Plot data for one sample pair
raw_image, crop_yield = crop_dataset[0]
figure = plt.figure()
figure.set_size_inches(18.5, 10.5)

print("type of the image: ", type(raw_image))

if type(raw_image) == torch.Tensor:
    plt.imshow(ToPILImage()(raw_image))
else:
    plt.imshow(raw_image)
    
print(f"Yield: {crop_yield}")
# Out:
# type of the image:  <class 'torch.Tensor'>
# Yield: tensor([[1028.4000]])

# %%
raw_image.shape
# Out:
# torch.Size([3, 224, 224])

# %%
# Now moving on to the machine learning model

# %%
dataloader = DataLoader(crop_dataset, batch_size=1, shuffle=False)

# %%
for feature, label in dataloader:
    print(f"Feature batch shape: {feature.size()}")
    print(label)
    print(f"Feature data type: {feature.dtype}")
    print(f"Label data type: {label.dtype}")
# Out:
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1028.4000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[944.3000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[959.3000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1183.6000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1137.9000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1015.]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1267.3000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1736.]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1957.5000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[2083.2000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[2135.7000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[2149.6001]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1976.5000]]])
# Feature data type: torch.float32
# Label data type: torch.float32
# Feature batch shape: torch.Size([1, 3, 224, 224])
# tensor([[[1443.5000]]])
# Feature data type: torch.float32
# Label data type: torch.float32

# %%
# Check device used
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Based on https://towardsdev.com/implement-resnet-with-pytorch-a9fb40a77448

class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample):
        super().__init__()
        if downsample:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=2),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
            self.shortcut = nn.Sequential()

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, input):
        shortcut = self.shortcut(input)
        input = nn.ReLU()(self.bn1(self.conv1(input)))
        input = nn.ReLU()(self.bn2(self.conv2(input)))
        input = input + shortcut
        return nn.ReLU()(input)

# %%
# Based on https://towardsdev.com/implement-resnet-with-pytorch-a9fb40a77448

class ResNet18(nn.Module):
    def __init__(self, in_channels, resblock, outputs=1):
        super().__init__()
        self.layer0 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=7, stride=2, padding=3),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )

        self.layer1 = nn.Sequential(
            resblock(64, 64, downsample=False),
            resblock(64, 64, downsample=False)
        )

        self.layer2 = nn.Sequential(
            resblock(64, 128, downsample=True),
            resblock(128, 128, downsample=False)
        )

        self.layer3 = nn.Sequential(
            resblock(128, 256, downsample=True),
            resblock(256, 256, downsample=False)
        )


        self.layer4 = nn.Sequential(
            resblock(256, 512, downsample=True),
            resblock(512, 512, downsample=False)
        )

        self.gap = torch.nn.AdaptiveAvgPool2d(1)
        self.fc = torch.nn.Linear(512, outputs)

    def forward(self, input):
        input = self.layer0(input)
        input = self.layer1(input)
        input = self.layer2(input)
        input = self.layer3(input)
        input = self.layer4(input)
        input = self.gap(input)
        input = torch.flatten(input)
        input = self.fc(input)

        return input

# %%
# Don't use pre-trained
model = ResNet18(in_channels = 3, resblock = ResBlock).to(device)
trainloader = dataloader # train_dataloader_resnet
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)
# optimizer = torch.optim.Adam
print(model)
# print(model(crop_dataset[3].to(device)))
# Out:
# ResNet18(
#   (layer0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (layer1): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# Potentially enhanced with transfer learning...?
# resnet_model = models.resnet18(pretrained=True).to(device)
# trainloader = dataloader # train_dataloader_resnet
# loss_fn = torch.nn.MSELoss()
# optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)
# # optimizer = torch.optim.Adam
# print(model)
# # print(model(crop_dataset[3].to(device)))

# %%
# Train model
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    correct, train_loss = 0, 0 
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()
        print(f"Actual {y}")
        print(f"Predicted {pred}")

        # Backpropagation
        optimizer.zero_grad()  
        loss.backward()
        optimizer.step() 
    train_loss /= num_batches
    return train_loss

# %%
epochs = 2000
for t in range(epochs):
    train_loss = train(trainloader, model, loss_fn, optimizer)
    # test_loss, test_acc = test(testloader, model, loss_fn)
    if t%1 == 0:
        print(f"Epoch {t}:")
        print(f"Avg loss: {train_loss:>8f}")
print("Done!")
# Out:
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1054.4343], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1031.6097], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1022.0643], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1083.4796], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1083.7450], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1017.1627], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1083.9148], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1084.2458], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1084.7812], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1085.2065], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1085.5602], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1085.8419], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1086.2163], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1086.8623], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 0:
# Avg loss: 385386.757553
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1029.5267], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1028.3073], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1021.5901], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1086.2668], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1086.4357], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1014.8727], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1086.4865], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1086.9861], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1087.4529], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1087.8423], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1088.2666], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1088.6709], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1088.9918], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1089.3447], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1:
# Avg loss: 382891.175767
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1025.1241], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1025.1691], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1014.9570], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1088.9850], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1089.2529], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1009.6132], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1089.3383], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1089.5961], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1090.0267], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1090.4396], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1090.8434], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1091.2236], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1091.5916], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1092.0143], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:
# Avg loss: 380505.602900
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1021.1793], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1021.8146], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1010.8703], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1091.6250], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1091.8644], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1005.3463], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1091.9855], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1092.2550], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1092.6331], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1092.9993], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1093.4250], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1093.7782], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1094.0828], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1094.4216], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 3:
# Avg loss: 378188.557537
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1017.7955], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1018.7873], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1007.1645], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1094.2749], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1094.4725], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1001.6782], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1094.6422], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1094.8676], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1095.2191], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1095.5828], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1095.9817], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1096.3237], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1096.6405], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1097.1123], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:
# Avg loss: 375879.584862
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1015.4147], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([1016.6488], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([1004.3944], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1096.8770], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1097.0830], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([999.0058], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1097.2690], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1097.4615], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1097.8278], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([1098.2257], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([1098.6296], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([1099.0201], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1099.4469], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1099.7583], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch
device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1728.5450], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1957.5217], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2082.2402], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2141.9583], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2147.4822], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1977.7037], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1440.7728], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1166:
# Avg loss: 11.008763
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1029.4321], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([945.9306], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([961.8894], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1181.2980], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1138.6625], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1012.5089], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1268.4437], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1745.5375], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1946.9418], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2083.5154], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2136.6345], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2147.2830], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1987.2131], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1444.5620], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1167:
# Avg loss: 24.893148
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1028.2089], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([944.2011], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([956.6354], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1183.1440], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1137.5093], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1019.7237], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1262.6962], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1724.7367], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1961.4468], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2078.8406], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2135.6882], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2148.1440], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1970.8280], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1451.4321], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1168:
# Avg loss: 22.119245
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1024.1790], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([946.4836], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([962.2180], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1185.0729], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1135.8695], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1014.3228], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1267.0524], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1749.7378], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1956.3130], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2085.4619], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2133.0017], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2146.9746], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1974.7050], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1426.7399], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1169:
# Avg loss: 37.961630
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1035.9131], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([946.4818], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([954.3760], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1191.1442], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1136.5104], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1008.4161], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1277.0359], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1725.8501], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1969.9281], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2082.4597], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2138.1582], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2147.4648], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1967.1227], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1455.4811], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1170:
# Avg loss: 55.895760
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1024.6609], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([951.8863], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([959.9586], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1166.9823], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1145.7860], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1019.3919], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1253.5813], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1744.6350], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1956.2246], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2086.5242], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2135.6052], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2147.7288], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1979.2004], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1443.5000]]], device='cuda:0')
# Predicted tensor([1442.1583], device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1171:
# Avg loss: 51.259966
# Actual tensor([[[1028.4000]]], device='cuda:0')
# Predicted tensor([1026.0367], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[944.3000]]], device='cuda:0')
# Predicted tensor([948.6793], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[959.3000]]], device='cuda:0')
# Predicted tensor([958.8102], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1183.6000]]], device='cuda:0')
# Predicted tensor([1194.7665], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1137.9000]]], device='cuda:0')
# Predicted tensor([1131.9083], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1015.]]], device='cuda:0')
# Predicted tensor([1015.9227], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1267.3000]]], device='cuda:0')
# Predicted tensor([1272.6493], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1736.]]], device='cuda:0')
# Predicted tensor([1725.6910], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1957.5000]]], device='cuda:0')
# Predicted tensor([1959.0160], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2083.2000]]], device='cuda:0')
# Predicted tensor([2081.1680], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2135.7000]]], device='cuda:0')
# Predicted tensor([2137.1169], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[2149.6001]]], device='cuda:0')
# Predicted tensor([2148.2891], device='cuda:0', grad_fn=<AddBackward0>)
# Actual tensor([[[1976.5000]]], device='cuda:0')
# Predicted tensor([1979.0441], device='cuda:0', grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17892/2984457807.py in <module>
#       1 epochs = 2000
#       2 for t in range(epochs):
# ----> 3     train_loss = train(trainloader, model, loss_fn, optimizer)
#       4     # test_loss, test_acc = test(testloader, model, loss_fn)
#       5     if t%1 == 0:
#
# ~\AppData\Local\Temp/ipykernel_17892/1211286239.py in train(dataloader, model, loss_fn, optimizer)
#      18         optimizer.zero_grad()
#      19         loss.backward()
# ---> 20         optimizer.step()
#      21     train_loss /= num_batches
#      22     return train_loss
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\optim\rmsprop.py in step(self, closure)
#     133
#     134
# --> 135             F.rmsprop(params_with_grad,
#     136                       grads,
#     137                       square_avgs,
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\optim\_functional.py in rmsprop(params, grads, square_avgs, grad_avgs, momentum_buffer_list, lr, alpha, eps, weight_decay, momentum, centered)
#     257             avg = square_avg.addcmul(grad_avg, grad_avg, value=-1).sqrt_().add_(eps)
#     258         else:
# --> 259             avg = square_avg.sqrt().add_(eps)
#     260
#     261         if momentum > 0:
#
# KeyboardInterrupt:

# %%
# Other model architectures

# %%
# class ConvNN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.network = nn.Sequential(
            
#             nn.Conv2d(3, 32, kernel_size = 3, padding = 1),
#             nn.ReLU(),
#             nn.Conv2d(32,64, kernel_size = 3, stride = 1, padding = 1),
#             nn.ReLU(),
#             nn.MaxPool2d(2,2),
        
#             nn.Conv2d(64, 128, kernel_size = 3, stride = 1, padding = 1),
#             nn.ReLU(),
#             nn.Conv2d(128 ,128, kernel_size = 3, stride = 1, padding = 1),
#             nn.ReLU(),
#             nn.MaxPool2d(2,2),
            
#             nn.Conv2d(128, 256, kernel_size = 3, stride = 1, padding = 1),
#             nn.ReLU(),
#             nn.Conv2d(256,256, kernel_size = 3, stride = 1, padding = 1),
#             nn.ReLU(),
#             nn.MaxPool2d(2,2),
            
#             nn.Flatten(),
#             nn.Linear(82944,1024),
#             nn.ReLU(),
#             nn.Linear(1024, 512),
#             nn.ReLU(),
#             nn.Linear(512,1)
#         )
    
#     def forward(self, xb):
#         return self.network(xb)

# %%
# # Basic Neural Network as outlined in lecture notes
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.flatten = nn.Flatten()
#         #self.linear1 = nn.Linear(28*28, 512)
#         #self.linear2 = nn.Linear(512, 512)
#         #self.linear3 = nn.Linear(512, 10)
#         #self.relu = nn.ReLU()
        
#         self.linear_relu_stack = nn.Sequential(
#             nn.Linear(28*28, 512),
#             nn.ReLU(),
#             nn.Linear(512, 512),
#             nn.ReLU(),
#             nn.Linear(512, 1),
#         )

#     def forward(self, x):
#         x = self.flatten(x)
#         #x = self.linear1(x)
#         #x = self.relu(x)
#         #x = self.linear2(x)
#         #x = self.relu(x)
#         #logits = self.linear3(x)
#         logits = self.linear_relu_stack(x)
#         return logits

# %%
# # Get cpu or gpu device for training.
# device = "cuda" if torch.cuda.is_available() else "cpu"
# print(f"Using {device} device")

    
# # Define model
# class ConvNN(nn.Module):
#     def __init__(self):
#         super(ConvNN, self).__init__()
#         self.conv_stack = nn.Sequential(
#             nn.Conv2d(3,6,5),
#             nn.ReLU(),
#             nn.MaxPool2d(2),
#             nn.Conv2d(6,12,5),
#             nn.ReLU(),
#             nn.MaxPool2d(2),
#             nn.Flatten(),
#             nn.ReLU(),
#             nn.Linear(192, 512),
#             nn.ReLU(),
#             nn.Linear(512, 3)
#         )

#     def forward(self, x):
#         logits = self.conv_stack(x)
#         return logits
    

# print(conv_model)
