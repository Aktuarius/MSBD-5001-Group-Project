# %%
# Import required packages\n",
import os
import numpy as np
import pandas as pd
import math
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchvision.transforms import ToPILImage
from torch.nn.init import kaiming_uniform
from torchvision.transforms import Resize, ToTensor, Compose
import matplotlib.pyplot as plt
import cv2

# %%
# Import the yield data as pandas data frame (Note this is saved as a csv file in base working directory)
file_path = os.path.join(os.getcwd()) + '/data/'
file_name = 'yield_PR.csv'
yield_data = pd.read_csv(file_path + file_name)

# %%
# yield_data[yield_data['Country Name'] == 'Kenya']['2005']

# %%
class CustomImageDataset():
    def __init__(self, hist_dir, crop_yield_table, transform=None, target_transform=None):  
        self.hist_dir = hist_dir # References the directory for each given country where the data is stored
        self.transform = transform
        self.target_transform = target_transform
        # load the files 
        filenames = [] # For every year, yields a numpy array of dimension 576 x 46
        crop_yields = []
        for filename in os.listdir(hist_dir):
            if filename != 'yield.csv' and filename != 'yield_PR.csv':
#             print(filename)
#             print(filename[:-9])
#             print(str(int(filename[-8:-4])))
#             print(crop_yield_table[crop_yield_table['Country Name'] == filename[:-9]][str(int(filename[-8:-4]))].to_numpy())
                filenames.append(filename)
                crop_yields.append(crop_yield_table[crop_yield_table['Country Name'] == filename[:-9]][str(int(filename[-8:-4]))].to_numpy())
#             print(crop_yields)
        self.filenames = filenames
        self.crop_yields = crop_yields
        
    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        hist_dir = os.path.join(self.hist_dir, self.filenames[idx])
        #hist = torch.from_numpy(np.load(hist_dir)).float()
        hist = np.load(hist_dir)
        # hist_3 = img2 = cv2.merge((hist,hist,hist))
        
        # Turn into 3 channel array (triplicate of single layer) --> to function with known model architectures
        hist_3 = np.zeros( ( np.array(hist).shape[0], np.array(hist).shape[1], 3 ) )
        hist_3[:,:,0] = hist # same value in each channel
        hist_3[:,:,1] = hist
        hist_3[:,:,2] = hist
        
        if self.transform:
            hist = self.transform(hist_3).float()
        crop_yield = torch.from_numpy(self.crop_yields[idx].reshape(-1, 1)).float()
        return hist, crop_yield

# %%
# Create_Training_Dataset
crop_dataset_train = CustomImageDataset('./train_data/', crop_yield_table = yield_data, transform = Compose([ToTensor(), Resize((224,224))]))

# Create_Training_Dataset
crop_dataset_test = CustomImageDataset('./test_data/', crop_yield_table = yield_data, transform = Compose([ToTensor(), Resize((224,224))]))

# %%
crop_dataset_train[3] # Shows for a given tensor which consists of a pair of 1) array of binned histogram data; and 2) yield output
# Out:
# (tensor([[[4.2608e-02, 4.2608e-02, 4.2533e-02,  ..., 4.6571e-02,
#            4.6918e-02, 4.6918e-02],
#           [2.7705e-01, 2.7705e-01, 2.7678e-01,  ..., 2.3345e-01,
#            2.3342e-01, 2.3342e-01],
#           [3.8722e-02, 3.8722e-02, 3.9051e-02,  ..., 7.1192e-02,
#            7.0520e-02, 7.0520e-02],
#           ...,
#           [3.9607e-01, 3.9607e-01, 3.9655e-01,  ..., 6.7015e-01,
#            6.7240e-01, 6.7240e-01],
#           [5.6489e-04, 5.6489e-04, 5.9094e-04,  ..., 2.6951e-03,
#            2.7263e-03, 2.7263e-03],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[4.2608e-02, 4.2608e-02, 4.2533e-02,  ..., 4.6571e-02,
#            4.6918e-02, 4.6918e-02],
#           [2.7705e-01, 2.7705e-01, 2.7678e-01,  ..., 2.3345e-01,
#            2.3342e-01, 2.3342e-01],
#           [3.8722e-02, 3.8722e-02, 3.9051e-02,  ..., 7.1192e-02,
#            7.0520e-02, 7.0520e-02],
#           ...,
#           [3.9607e-01, 3.9607e-01, 3.9655e-01,  ..., 6.7015e-01,
#            6.7240e-01, 6.7240e-01],
#           [5.6489e-04, 5.6489e-04, 5.9094e-04,  ..., 2.6951e-03,
#            2.7263e-03, 2.7263e-03],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[4.2608e-02, 4.2608e-02, 4.2533e-02,  ..., 4.6571e-02,
#            4.6918e-02, 4.6918e-02],
#           [2.7705e-01, 2.7705e-01, 2.7678e-01,  ..., 2.3345e-01,
#            2.3342e-01, 2.3342e-01],
#           [3.8722e-02, 3.8722e-02, 3.9051e-02,  ..., 7.1192e-02,
#            7.0520e-02, 7.0520e-02],
#           ...,
#           [3.9607e-01, 3.9607e-01, 3.9655e-01,  ..., 6.7015e-01,
#            6.7240e-01, 6.7240e-01],
#           [5.6489e-04, 5.6489e-04, 5.9094e-04,  ..., 2.6951e-03,
#            2.7263e-03, 2.7263e-03],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]),
#  tensor([[1500.8000]]))

# %%
crop_dataset_train[3][0].shape # For each binned histogram data, consists of 576 observations across 29 dimensions
# Out:
# torch.Size([3, 224, 224])

# %%
# Plot data for one sample pair
raw_image, crop_yield = crop_dataset_train[0]
figure = plt.figure()
figure.set_size_inches(18.5, 10.5)

print("type of the image: ", type(raw_image))

if type(raw_image) == torch.Tensor:
    plt.imshow(ToPILImage()(raw_image))
else:
    plt.imshow(raw_image)
    
print(f"Yield: {crop_yield}")
# Out:
# type of the image:  <class 'torch.Tensor'>
# Yield: tensor([[1058.6000]])

# %%
# Initialize data loaders
train_dataloader = DataLoader(crop_dataset_train, batch_size=1, shuffle=False)
test_dataloader = DataLoader(crop_dataset_test, batch_size=1, shuffle=False)

# %%
# for feature, label in dataloader:
#     print(f"Feature batch shape: {feature.size()}")
#     print(label)
#     print(f"Feature data type: {feature.dtype}")
#     print(f"Label data type: {label.dtype}")

# %%
# Check device used
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# # Basic Neural Network as outlined in lecture notes
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.flatten = nn.Flatten()
#         #self.linear1 = nn.Linear(28*28, 512)
#         #self.linear2 = nn.Linear(512, 512)
#         #self.linear3 = nn.Linear(512, 10)
#         #self.relu = nn.ReLU()
        
#         self.linear_relu_stack = nn.Sequential(
#             nn.Linear(28*28, 512),
#             nn.ReLU(),
#             nn.Linear(512, 512),
#             nn.ReLU(),
#             nn.Linear(512, 1),
#         )

#     def forward(self, x):
#         x = self.flatten(x)
#         #x = self.linear1(x)
#         #x = self.relu(x)
#         #x = self.linear2(x)
#         #x = self.relu(x)
#         #logits = self.linear3(x)
#         logits = self.linear_relu_stack(x)
#         return logits

# %%
# Based on https://towardsdev.com/implement-resnet-with-pytorch-a9fb40a77448

class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample):
        super().__init__()
        if downsample:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=2),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
            self.shortcut = nn.Sequential()

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, input):
        shortcut = self.shortcut(input)
        input = nn.ReLU()(self.bn1(self.conv1(input)))
        input = nn.ReLU()(self.bn2(self.conv2(input)))
        input = input + shortcut
        return nn.ReLU()(input)

# %%
# Based on https://towardsdev.com/implement-resnet-with-pytorch-a9fb40a77448

class ResNet18(nn.Module):
    def __init__(self, in_channels, resblock, outputs=1):
        super().__init__()
        self.layer0 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=7, stride=2, padding=3),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )

        self.layer1 = nn.Sequential(
            resblock(64, 64, downsample=False),
            resblock(64, 64, downsample=False)
        )

        self.layer2 = nn.Sequential(
            resblock(64, 128, downsample=True),
            resblock(128, 128, downsample=False)
        )

        self.layer3 = nn.Sequential(
            resblock(128, 256, downsample=True),
            resblock(256, 256, downsample=False)
        )


        self.layer4 = nn.Sequential(
            resblock(256, 512, downsample=True),
            resblock(512, 512, downsample=False)
        )

        self.gap = torch.nn.AdaptiveAvgPool2d(1)
        self.fc = torch.nn.Linear(512, outputs)

    def forward(self, input):
        input = self.layer0(input)
        input = self.layer1(input)
        input = self.layer2(input)
        input = self.layer3(input)
        input = self.layer4(input)
        input = self.gap(input)
        input = torch.flatten(input)
        input = self.fc(input)

        return input

# %%
# Potentially use pre-trained model
# resnet_model = models.resnet18(pretrained=True).to(device) 

# Don't use pre-trained
model = ResNet18(in_channels = 3, resblock = ResBlock).to(device)
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)
print(model)

# print(model(crop_dataset[3].to(device)))
# optimizer = torch.optim.Adam
# Out:
# ResNet18(
#   (layer0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (layer1): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): ResBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Sequential()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# Train model
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    correct, train_loss = 0, 0 
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()
#         print(f"Actual {y}")
#         print(f"Predicted {pred}")

        # Backpropagation
        optimizer.zero_grad()  
        loss.backward()
        optimizer.step() 
    train_loss /= num_batches
    return train_loss

# %%
def test(dataloader, model):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval() 
    
    test_val = pd.DataFrame(columns = ['Actual', 'Predicted', 'Error', 'Error_sq', 'Perc_Err'])
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device).item()
            pred = model(X).item()
#             print(f"Actual {y}")
#             print(f"Predicted {pred}")
#             print(f"Error {pred - y}")
#             print(f"Percentage Error {(pred - y) / y}")
                    
            test_val = test_val.append({'Actual' : y, 'Predicted' : pred , 'Error' : abs(pred - y),  'Error_sq': (pred - y)**2, 'Perc_Err' : abs(pred - y) / y}, ignore_index = True)

    return test_val

# %%
epochs = 500
train_loss_history = []
test_history_RMSE = []
test_history_MAPE = []

for t in range(epochs):
    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    test_vals = test(test_dataloader, model)
    train_loss_history.append(train_loss)
    test_history_RMSE.append(math.sqrt(test_vals['Error_sq'].sum() / test_vals['Error_sq'].count()))
    test_history_MAPE.append(test_vals['Perc_Err'].mean())
    # test_loss, test_acc = test(testloader, model, loss_fn)
    if t%1 == 0:
        print(f"Epoch {t}:")
        print(f"Avg training loss: {train_loss:>8f}")
        print(f"Root Mean Squared Error: {math.sqrt(test_vals['Error_sq'].sum() / test_vals['Error_sq'].count())}")
        print(f"Mean Average Percentage Error: {test_vals['Perc_Err'].mean()}")
print("Done!")
# Out:
# C:\Users\paulr\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\loss.py:529: UserWarning: Using a target size (torch.Size([1, 1, 1])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0:
# Avg training loss: 4024094.205679
# Root Mean Squared Error: 2048.3495224948288
# Mean Average Percentage Error: 0.9733185239010915
# Epoch 1:
# Avg training loss: 3959353.373590
# Root Mean Squared Error: 2031.290658705919
# Mean Average Percentage Error: 0.9532165013464783
# Epoch 2:
# Avg training loss: 3890013.498509
# Root Mean Squared Error: 2013.3435887141286
# Mean Average Percentage Error: 0.9318862348429616
# Epoch 3:
# Avg training loss: 3818458.850453
# Root Mean Squared Error: 1994.3244516132131
# Mean Average Percentage Error: 0.9090837482819634
# Epoch 4:
# Avg training loss: 3743971.399041
# Root Mean Squared Error: 1974.3738932289
# Mean Average Percentage Error: 0.8850255824054293
# Epoch 5:
# Avg training loss: 3666836.559091
# Root Mean Squared Error: 1953.5576401235996
# Mean Average Percentage Error: 0.8597226554000301
# Epoch 6:
# Avg training loss: 3587581.063699
# Root Mean Squared Error: 1931.9258833099825
# Mean Average Percentage Error: 0.8331871439067962
# Epoch 7:
# Avg training loss: 3506762.578557
# Root Mean Squared Error: 1909.5221165838677
# Mean Average Percentage Error: 0.805388085966408
# Epoch 8:
# Avg training loss: 3424829.091987
# Root Mean Squared Error: 1886.525543277645
# Mean Average Percentage Error: 0.7765825649209024
# Epoch 9:
# Avg training loss: 3342286.463228
# Root Mean Squared Error: 1863.0237414681978
# Mean Average Percentage Error: 0.7467911690186226
# Epoch 10:
# Avg training loss: 3259624.393011
# Root Mean Squared Error: 1839.2888563724464
# Mean Average Percentage Error: 0.716380030461964
# Epoch 11:
# Avg training loss: 3177373.890590
# Root Mean Squared Error: 1815.1490335634498
# Mean Average Percentage Error: 0.6849732534341703
# Epoch 12:
# Avg training loss: 3095952.781309
# Root Mean Squared Error: 1790.9363608935307
# Mean Average Percentage Error: 0.6599492586523611
# Epoch 13:
# Avg training loss: 3015796.167060
# Root Mean Squared Error: 1766.6778438824686
# Mean Average Percentage Error: 0.6352264202171006
# Epoch 14:
# Avg training loss: 2937367.296952
# Root Mean Squared Error: 1742.6128226322958
# Mean Average Percentage Error: 0.610364205165214
# Epoch 15:
# Avg training loss: 2861020.035196
# Root Mean Squared Error: 1718.7558984072964
# Mean Average Percentage Error: 0.5852336447421287
# Epoch 16:
# Avg training loss: 2787142.761005
# Root Mean Squared Error: 1695.1656970102079
# Mean Average Percentage Error: 0.5601302308751154
# Epoch 17:
# Avg training loss: 2716011.801184
# Root Mean Squared Error: 1672.0930480316388
# Mean Average Percentage Error: 0.5459429779690856
# Epoch 18:
# Avg training loss: 2641735.078699
# Root Mean Squared Error: 1640.4960526783834
# Mean Average Percentage Error: 0.52668556533947
# Avg training loss: 1744251.541775
# Root Mean Squared Error: 1385.0802232595815
# Mean Average Percentage Error: 0.4538534768692454
# Epoch 42:
# Avg training loss: 1700168.263158
# Root Mean Squared Error: 1436.9190362475745
# Mean Average Percentage Error: 0.4624991434590407
# Epoch 43:
# Avg training loss: 1673490.760063
# Root Mean Squared Error: 1455.6147182101492
# Mean Average Percentage Error: 0.4837928399459239
# Epoch 44:
# Avg training loss: 1654444.831779
# Root Mean Squared Error: 1459.7224358971705
# Mean Average Percentage Error: 0.5004891939207297
# Epoch 45:
# Avg training loss: 1638469.523448
# Root Mean Squared Error: 1479.39631706562
# Mean Average Percentage Error: 0.5038272076893424
# Epoch 46:
# Avg training loss: 1616050.165494
# Root Mean Squared Error: 1506.3940069523946
# Mean Average Percentage Error: 0.512809986915208
# Epoch 47:
# Avg training loss: 1606022.821092
# Root Mean Squared Error: 1431.0121478923784
# Mean Average Percentage Error: 0.584643266841429
# Epoch 48:
# Avg training loss: 1584547.331371
# Root Mean Squared Error: 1463.4038224659196
# Mean Average Percentage Error: 0.5260472577716955
# Epoch 49:
# Avg training loss: 1564888.954808
# Root Mean Squared Error: 1512.0943961215924
# Mean Average Percentage Error: 0.5171116986683992
# Epoch 50:
# Avg training loss: 1548420.544299
# Root Mean Squared Error: 1518.9932338262204
# Mean Average Percentage Error: 0.5025285051124726
# Epoch 51:
# Avg training loss: 1536508.322438
# Root Mean Squared Error: 1438.4890703339274
# Mean Average Percentage Error: 0.47382224259712385
# Epoch 52:
# Avg training loss: 1520847.271593
# Root Mean Squared Error: 1492.0284039937674
# Mean Average Percentage Error: 0.5122647924145889
# Epoch 53:
# Avg training loss: 1509988.543633
# Root Mean Squared Error: 1450.9036140323942
# Mean Average Percentage Error: 0.4963225288681365
# Epoch 54:
# Avg training loss: 1498277.316721
# Root Mean Squared Error: 1419.6236151065484
# Mean Average Percentage Error: 0.4815523783776167
# Epoch 55:
# Avg training loss: 1483004.682568
# Root Mean Squared Error: 1407.0162301436383
# Mean Average Percentage Error: 0.4801198771488161
# Epoch 56:
# Avg training loss: 1469646.964155
# Root Mean Squared Error: 1449.6880667294226
# Mean Average Percentage Error: 0.5390449310577865
# Epoch 57:
# Avg training loss: 1465507.366732
# Root Mean Squared Error: 1439.0889380106212
# Mean Average Percentage Error: 0.4921277906177731
# Epoch 58:
# Avg training loss: 1453148.892779
# Root Mean Squared Error: 1411.1033220047311
# Mean Average Percentage Error: 0.5558390186571203
# Epoch 59:
# Avg training loss: 1449657.620270
# Root Mean Squared Error: 1362.0041953583343
# Mean Average Percentage Error: 0.5361095078498338
# Epoch 60:
# Avg training loss: 1437401.006790
# Root Mean Squared Error: 1400.604504825902
# Mean Average Percentage Error: 0.5829334835324625
# Epoch 61:
# Avg training loss: 1423672.295068
# Root Mean Squared Error: 1402.675607953914
# Mean Average Percentage Error: 0.5476864868186779
# Epoch 62:
# Avg training loss: 1410504.900819
# Root Mean Squared Error: 1434.8624838597868
# Mean Average Percentage Error: 0.5861421649413526
# Epoch 63:
# Avg training loss: 1402752.727770
# Root Mean Squared Error: 1376.611306090591
# Mean Average Percentage Error: 0.5500439293210205
# Epoch 64:
# Avg training loss: 1392425.003485
# Root Mean Squared Error: 1418.1828315557063
# Mean Average Percentage Error: 0.56604293808256
# Epoch 65:
# Avg training loss: 1383709.861219
# Root Mean Squared Error: 1372.8047344428098
# Mean Average Percentage Error: 0.5743696129888781
# Epoch 66:
# Avg training loss: 1378662.335845
# Root Mean Squared Error: 1354.2597341985895
# Mean Average Percentage Error: 0.5276954904521414
# Epoch 67:
# Avg training loss: 1368957.520839
# Root Mean Squared Error: 1338.811049891131
# Mean Average Percentage Error: 0.6147752849986398
# Epoch 68:
# Avg training loss: 1361837.947586
# Root Mean Squared Error: 1455.0209180277172
# Mean Average Percentage Error: 0.7754178104876371
# Epoch 69:
# Avg training loss: 1350914.036444
# Root Mean Squared Error: 1371.7544778783863
# Mean Average Percentage Error: 0.658559699921738
# Epoch 70:
# Avg training loss: 1347430.288290
# Root Mean Squared Error: 1313.0269251299578
# Mean Average Percentage Error: 0.579450344891672
# Epoch 71:
# Avg training loss: 1340399.774415
# Root Mean Squared Error: 1344.506197504465
# Mean Average Percentage Error: 0.6424892559844071
# Epoch 72:
# Avg training loss: 1330571.939530
# Root Mean Squared Error: 1311.3288938292258
# Mean Average Percentage Error: 0.6230798953329758
# Epoch 73:
# Avg training loss: 1327212.786168
# Root Mean Squared Error: 1436.314003679763
# Mean Average Percentage Error: 0.5999688281246485
# Epoch 74:
# Avg training loss: 1314245.419746
# Root Mean Squared Error: 1286.7414350484494
# Mean Average Percentage Error: 0.5909077166251446
# Epoch 75:
# Avg training loss: 1313554.873138
# Root Mean Squared Error: 1370.6115779300915
# Mean Average Percentage Error: 0.6788900784392181
# Epoch 76:
# Avg training loss: 1300338.127845
# Root Mean Squared Error: 1309.23766675115
# Mean Average Percentage Error: 0.5982491610815697
# Epoch 77:
# Avg training loss: 1300562.332215
# Root Mean Squared Error: 1510.866841020688
# Mean Average Percentage Error: 0.6296502731772449
# Epoch 78:
# Avg training loss: 1293107.722337
# Root Mean Squared Error: 1426.5416463826243
# Mean Average Percentage Error: 0.6051605515656986
# Epoch 79:
# Avg training loss: 1280839.618298
# Root Mean Squared Error: 1336.149015196824
# Mean Average Percentage Error: 0.5207077213395206
# Epoch 80:
# Avg training loss: 1276312.710362
# Root Mean Squared Error: 1390.013630774124
# Mean Average Percentage Error: 0.5981248687518967
# Epoch 81:
# Avg training loss: 1266809.907740
# Root Mean Squared Error: 1328.8125393944501
# Mean Average Percentage Error: 0.6060576078441914
# Epoch 82:
# Avg training loss: 1263173.462026
# Root Mean Squared Error: 1398.555369089092
# Mean Average Percentage Error: 0.5658002898775861
# Epoch 83:
# Avg training loss: 1257788.337481
# Root Mean Squared Error: 1297.6399085274859
# Mean Average Percentage Error: 0.5237190636564943
# Epoch 84:
# Avg training loss: 1250040.172998
# Root Mean Squared Error: 1383.4281001993731
# Mean Average Percentage Error: 0.5527559994639333
# Epoch 85:
# Avg training loss: 1245164.520991
# Root Mean Squared Error: 1289.1945652331822
# Mean Average Percentage Error: 0.5592330864154509
# Root Mean Squared Error: 1402.8651458340737
# Mean Average Percentage Error: 0.6122548360041206
# Epoch 109:
# Avg training loss: 1107099.745785
# Root Mean Squared Error: 1422.5551907350348
# Mean Average Percentage Error: 0.6651388028386136
# Epoch 110:
# Avg training loss: 1100489.968455
# Root Mean Squared Error: 1303.524174098986
# Mean Average Percentage Error: 0.5139378253976363
# Epoch 111:
# Avg training loss: 1096431.899800
# Root Mean Squared Error: 1334.4396241864074
# Mean Average Percentage Error: 0.5704442724141953
# Epoch 112:
# Avg training loss: 1091316.620507
# Root Mean Squared Error: 1394.3474372196674
# Mean Average Percentage Error: 0.6018550613685669
# Epoch 113:
# Avg training loss: 1083530.732119
# Root Mean Squared Error: 1276.4493847105814
# Mean Average Percentage Error: 0.5238815589230227
# Epoch 114:
# Avg training loss: 1078731.523094
# Root Mean Squared Error: 1296.9744972703832
# Mean Average Percentage Error: 0.5620142380375557
# Epoch 115:
# Avg training loss: 1073113.542584
# Root Mean Squared Error: 1261.0892377370735
# Mean Average Percentage Error: 0.5895722320572824
# Epoch 116:
# Avg training loss: 1066445.107039
# Root Mean Squared Error: 1327.5905920642917
# Mean Average Percentage Error: 0.6722179870349227
# Epoch 117:
# Avg training loss: 1063201.229694
# Root Mean Squared Error: 1350.02981376822
# Mean Average Percentage Error: 0.554096387261388
# Epoch 118:
# Avg training loss: 1056133.761813
# Root Mean Squared Error: 1413.1124787950741
# Mean Average Percentage Error: 0.602425651694911
# Epoch 119:
# Avg training loss: 1050224.240383
# Root Mean Squared Error: 1343.6885446735
# Mean Average Percentage Error: 0.5667196558187626
# Epoch 120:
# Avg training loss: 1048238.007028
# Root Mean Squared Error: 1431.962431964846
# Mean Average Percentage Error: 0.6734652766378091
# Epoch 121:
# Avg training loss: 1038558.445167
# Root Mean Squared Error: 1405.3286878287354
# Mean Average Percentage Error: 0.6290654138083492
# Epoch 122:
# Avg training loss: 1034510.605535
# Root Mean Squared Error: 1350.5771492393228
# Mean Average Percentage Error: 0.5665651876233546
# Epoch 123:
# Avg training loss: 1028934.946937
# Root Mean Squared Error: 1338.825408367977
# Mean Average Percentage Error: 0.5384060522724803
# Epoch 124:
# Avg training loss: 1023283.397230
# Root Mean Squared Error: 1377.1138871044086
# Mean Average Percentage Error: 0.6276875624329823
# Epoch 125:
# Avg training loss: 1017576.170969
# Root Mean Squared Error: 1419.454498465785
# Mean Average Percentage Error: 0.5986812665079582
# Epoch 126:
# Avg training loss: 1011547.257945
# Root Mean Squared Error: 1349.4668013747153
# Mean Average Percentage Error: 0.5463235695725734
# Epoch 127:
# Avg training loss: 1006313.212692
# Root Mean Squared Error: 1369.5406049901253
# Mean Average Percentage Error: 0.5566718322086234
# Epoch 128:
# Avg training loss: 1004036.860527
# Root Mean Squared Error: 1311.6985030557928
# Mean Average Percentage Error: 0.6046709723448
# Epoch 129:
# Avg training loss: 995357.193737
# Root Mean Squared Error: 1316.4702856521208
# Mean Average Percentage Error: 0.6122110823170227
# Epoch 130:
# Avg training loss: 991167.605583
# Root Mean Squared Error: 1384.7427130579833
# Root Mean Squared Error: 1544.3306232920686
# Mean Average Percentage Error: 0.6696837559294013
# Epoch 222:
# Avg training loss: 539071.696199
# Root Mean Squared Error: 1560.5061407281314
# Mean Average Percentage Error: 0.6435208685203798
# Epoch 223:
# Avg training loss: 533422.437761
# Root Mean Squared Error: 1496.8249405105025
# Mean Average Percentage Error: 0.6610030773389274
# Epoch 224:
# Avg training loss: 529616.666804
# Root Mean Squared Error: 1591.3545594601262
# Mean Average Percentage Error: 0.6642816905102689
# Epoch 225:
# Avg training loss: 526221.697262
# Root Mean Squared Error: 1543.3333846361852
# Mean Average Percentage Error: 0.5878810987768796
# Epoch 226:
# Avg training loss: 522187.338433
# Root Mean Squared Error: 1527.1169055284038
# Mean Average Percentage Error: 0.6560311915734508
# Epoch 227:
# Avg training loss: 518247.705034
# Root Mean Squared Error: 1552.9265452190034
# Mean Average Percentage Error: 0.6197679142646189
# Epoch 228:
# Avg training loss: 513930.904357
# Root Mean Squared Error: 1555.7336287649953
# Mean Average Percentage Error: 0.6418276037567456
# Epoch 229:
# Avg training loss: 510201.117071
# Root Mean Squared Error: 1529.0719629781227
# Mean Average Percentage Error: 0.6478061846089584
# Epoch 230:
# Avg training loss: 506735.157546
# Root Mean Squared Error: 1489.6613941147762
# Mean Average Percentage Error: 0.6525307551336206
# Epoch 231:
# Avg training loss: 502481.975106
# Root Mean Squared Error: 1536.9008079742882
# Mean Average Percentage Error: 0.6355504034915214
# Epoch 232:
# Avg training loss: 500610.355972
# Root Mean Squared Error: 1522.0512539488811
# Mean Average Percentage Error: 0.60990825961071
# Epoch 233:
# Avg training loss: 495615.463971
# Root Mean Squared Error: 1582.1517400274324
# Mean Average Percentage Error: 0.5999423249530695
# Epoch 234:
# Avg training loss: 490856.443193
# Root Mean Squared Error: 1543.413917362653
# Mean Average Percentage Error: 0.5660686949023231
# Epoch 235:
# Avg training loss: 488808.754398
# Root Mean Squared Error: 1545.4066918430995
# Mean Average Percentage Error: 0.6049282366522353
# Epoch 236:
# Avg training loss: 484907.887456
# Root Mean Squared Error: 1561.1763231659868
# Mean Average Percentage Error: 0.6237508466507833
# Epoch 237:
# Avg training loss: 480583.862952
# Root Mean Squared Error: 1573.067561763227
# Mean Average Percentage Error: 0.6269644149517349
# Epoch 238:
# Avg training loss: 477019.573933
# Root Mean Squared Error: 1631.3586715160538
# Mean Average Percentage Error: 0.6245311595726155
# Epoch 239:
# Avg training loss: 473979.999748
# Root Mean Squared Error: 1522.4865885189938
# Mean Average Percentage Error: 0.6031825099194217
# Epoch 240:
# Avg training loss: 470651.549231
# Root Mean Squared Error: 1472.3066435846208
# Mean Average Percentage Error: 0.6044213050408801
# Epoch 241:
# Avg training loss: 466473.554027
# Root Mean Squared Error: 1515.862912194493
# Mean Average Percentage Error: 0.719955658394868
# Epoch 242:
# Avg training loss: 472829.126204
# Root Mean Squared Error: 1549.8171530631287
# Mean Average Percentage Error: 0.666099033933712
# Epoch 243:
# Avg training loss: 460649.573461
# Root Mean Squared Error: 1532.4657895202993
# Mean Average Percentage Error: 0.682130291123048
# Epoch 244:
# Avg training loss: 457633.084025
# Root Mean Squared Error: 1585.5222318431659
# Mean Average Percentage Error: 0.62669680070716
# Epoch 245:
# Avg training loss: 453916.360540
# Root Mean Squared Error: 1629.536262324815
# Mean Average Percentage Error: 0.6388682663254184
# Epoch 246:
# Avg training loss: 450259.207874
# Root Mean Squared Error: 1618.5702294426524
# Mean Average Percentage Error: 0.620161336199067
# Epoch 247:
# Avg training loss: 447681.020314
# Root Mean Squared Error: 1569.8044230389166
# Mean Average Percentage Error: 0.6238875388064404
# Epoch 248:
# Avg training loss: 443967.620141
# Root Mean Squared Error: 1602.5635564929944
# Mean Average Percentage Error: 0.6207613727721573
# Epoch 249:
# Avg training loss: 440743.497867
# Root Mean Squared Error: 1562.5677784400148
# Mean Average Percentage Error: 0.5884848768640114
# Epoch 250:
# Avg training loss: 436932.829981
# Root Mean Squared Error: 1537.8990363435375
# Mean Average Percentage Error: 0.5428560039813478
# Epoch 251:
# Avg training loss: 434611.097211
# Root Mean Squared Error: 1610.9456649682138
# Mean Average Percentage Error: 0.5943722678729857
# Epoch 252:
# Avg training loss: 431767.307257
# Root Mean Squared Error: 1572.8421081345994
# Mean Average Percentage Error: 0.614505710869054
# Epoch 253:
# Avg training loss: 427083.977550
# Root Mean Squared Error: 1583.4606696979897
# Mean Average Percentage Error: 0.6426898874636315
# Epoch 254:
# Avg training loss: 424648.901842
# Root Mean Squared Error: 1569.7453428690983
# Mean Average Percentage Error: 0.6022793981983945
# Epoch 255:
# Avg training loss: 421026.427749
# Root Mean Squared Error: 1590.4280033904606
# Mean Average Percentage Error: 0.6199529118953566
# Epoch 256:
# Avg training loss: 416715.433323
# Root Mean Squared Error: 1610.4323060196425
# Mean Average Percentage Error: 0.6213437814733717
# Epoch 257:
# Avg training loss: 415467.713914
# Root Mean Squared Error: 1502.079693163282
# Mean Average Percentage Error: 0.6147280435730418
# Epoch 258:
# Avg training loss: 411526.064210
# Root Mean Squared Error: 1601.6319279649474
# Mean Average Percentage Error: 0.6331138747835745
# Epoch 259:
# Avg training loss: 410746.662877
# Root Mean Squared Error: 1560.169551202059
# Mean Average Percentage Error: 0.61645659083902
# Epoch 260:
# Avg training loss: 405025.703179
# Root Mean Squared Error: 1650.4569300053624
# Mean Average Percentage Error: 0.6141150103247134
# Epoch 261:
# Avg training loss: 400521.626202
# Root Mean Squared Error: 1537.7049466044666
# Mean Average Percentage Error: 0.6126582952884934
# Epoch 262:
# Avg training loss: 398359.469205
# Root Mean Squared Error: 1625.2606112539042
# Mean Average Percentage Error: 0.6135837022325279
# Epoch 263:
# Avg training loss: 395888.802413
# Root Mean Squared Error: 1541.9136431590134
# Mean Average Percentage Error: 0.6213969997150132
# Epoch 264:
# Avg training loss: 392758.119465
# Root Mean Squared Error: 1599.5985006817646
# Mean Average Percentage Error: 0.6098943963657347
# Epoch 265:
# Avg training loss: 388376.689541
# Root Mean Squared Error: 1571.2276960473223
# Mean Average Percentage Error: 0.5847882197991952
# Epoch 266:
# Avg training loss: 388302.965910
# Root Mean Squared Error: 1523.1260515900256
# Root Mean Squared Error: 1642.908931436736
# Mean Average Percentage Error: 0.6381811905736304
# Epoch 290:
# Avg training loss: 313158.328404
# Root Mean Squared Error: 1606.3257491465165
# Mean Average Percentage Error: 0.6556303449671013
# Epoch 291:
# Avg training loss: 311205.059389
# Root Mean Squared Error: 1529.3877319679727
# Mean Average Percentage Error: 0.7235285507173361
# Epoch 292:
# Avg training loss: 307355.451564
# Root Mean Squared Error: 1647.1639981615474
# Mean Average Percentage Error: 0.670602318641629
# Epoch 293:
# Avg training loss: 304875.954718
# Root Mean Squared Error: 1594.545025730111
# Mean Average Percentage Error: 0.6496164642453619
# Epoch 294:
# Avg training loss: 301804.635107
# Root Mean Squared Error: 1693.6742981120703
# Mean Average Percentage Error: 0.6256269266631637
# Epoch 295:
# Avg training loss: 299029.876635
# Root Mean Squared Error: 1616.80193222424
# Mean Average Percentage Error: 0.6002123772152795
# Epoch 296:
# Avg training loss: 296749.531382
# Root Mean Squared Error: 1641.838083575993
# Mean Average Percentage Error: 0.61825533558561
# Epoch 297:
# Avg training loss: 293444.602004
# Root Mean Squared Error: 1613.258574362359
# Mean Average Percentage Error: 0.6485688782651314
# Epoch 298:
# Avg training loss: 290475.120271
# Root Mean Squared Error: 1660.5164524662562
# Mean Average Percentage Error: 0.6292486022750299
# Epoch 299:
# Avg training loss: 287653.828499
# Root Mean Squared Error: 1636.223591916265
# Mean Average Percentage Error: 0.6250092226846259
# Epoch 300:
# Avg training loss: 285586.702402
# Root Mean Squared Error: 1628.9910815787684
# Mean Average Percentage Error: 0.5977394664410723
# Epoch 301:
# Avg training loss: 281639.406280
# Root Mean Squared Error: 1686.8960483096484
# Mean Average Percentage Error: 0.6141913853620538
# Epoch 302:
# Avg training loss: 279885.021923
# Root Mean Squared Error: 1654.2513611124446
# Mean Average Percentage Error: 0.6104699332900231
# Epoch 303:
# Avg training loss: 276119.428246
# Root Mean Squared Error: 1655.8886069237074
# Mean Average Percentage Error: 0.6081125832697961
# Epoch 304:
# Avg training loss: 274171.224727
# Root Mean Squared Error: 1588.9822732341336
# Mean Average Percentage Error: 0.6384415509919683
# Epoch 305:
# Avg training loss: 270877.504900
# Root Mean Squared Error: 1637.9908931350806
# Mean Average Percentage Error: 0.6408547144487851
# Epoch 306:
# Avg training loss: 269286.067063
# Root Mean Squared Error: 1630.9391247475908
# Mean Average Percentage Error: 0.6490857762786301
# Epoch 307:
# Avg training loss: 264945.840506
# Root Mean Squared Error: 1674.514206731835
# Mean Average Percentage Error: 0.6440189440172609
# Epoch 308:
# Avg training loss: 263116.382781
# Root Mean Squared Error: 1588.2795386325568
# Mean Average Percentage Error: 0.5933441692358626
# Epoch 309:
# Avg training loss: 260333.200166
# Root Mean Squared Error: 1643.130466556983
# Mean Average Percentage Error: 0.5898149729304434
# Epoch 310:
# Avg training loss: 258203.808675
# Root Mean Squared Error: 1685.4844441019811
# Mean Average Percentage Error: 0.6141272125320536
# Epoch 311:
# Avg training loss: 254164.545797
# Root Mean Squared Error: 1662.267129346109
# Mean Average Percentage Error: 0.6191522042847966
# Mean Average Percentage Error: 0.6254291833644854
# Epoch 335:
# Avg training loss: 193358.094750
# Root Mean Squared Error: 1649.0607038504966
# Mean Average Percentage Error: 0.6133162202956463
# Epoch 336:
# Avg training loss: 192970.959885
# Root Mean Squared Error: 1649.1535481384494
# Mean Average Percentage Error: 0.6181066996685552
# Epoch 337:
# Avg training loss: 188642.179146
# Root Mean Squared Error: 1674.3238541207706
# Mean Average Percentage Error: 0.6300780642141132
# Epoch 338:
# Avg training loss: 186082.379423
# Root Mean Squared Error: 1709.600315599771
# Mean Average Percentage Error: 0.6251884169105437
# Epoch 339:
# Avg training loss: 184746.211918
# Root Mean Squared Error: 1666.1999235453966
# Mean Average Percentage Error: 0.5820979993565936
# Epoch 340:
# Avg training loss: 181546.614669
# Root Mean Squared Error: 1676.7566408625194
# Mean Average Percentage Error: 0.6109726348868363
# Epoch 341:
# Avg training loss: 179404.096771
# Root Mean Squared Error: 1677.8565829292281
# Mean Average Percentage Error: 0.6327000907782616
# Epoch 342:
# Avg training loss: 177335.264777
# Root Mean Squared Error: 1677.1936828218213
# Mean Average Percentage Error: 0.5926061671340487
# Epoch 343:
# Avg training loss: 174728.304314
# Root Mean Squared Error: 1657.6927412706327
# Mean Average Percentage Error: 0.5703746722162694
# Epoch 344:
# Avg training loss: 171901.664387
# Root Mean Squared Error: 1653.5139025874125
# Mean Average Percentage Error: 0.6448205403887617
# Epoch 345:
# Avg training loss: 170476.711094
# Root Mean Squared Error: 1725.0652553594548
# Mean Average Percentage Error: 0.6478996217534736
# ...
# Epoch 383:
# Avg training loss: 95437.021778
# Root Mean Squared Error: 1687.5773368255682
# Mean Average Percentage Error: 0.6174486906666543
# Epoch 384:
# Avg training loss: 94430.043421
# Root Mean Squared Error: 1707.9509105153727
# Mean Average Percentage Error: 0.6325126763643591
# Epoch 385:
# Avg training loss: 92264.106060
# Root Mean Squared Error: 1728.2485055573804
# Mean Average Percentage Error: 0.648896597792106
# Epoch 386:
# Avg training loss: 91257.494444
# Root Mean Squared Error: 1746.7987234427655
# Mean Average Percentage Error: 0.6793062011707917
# Epoch 387:
# Avg training loss: 89308.969338
# Root Mean Squared Error: 1829.9447441698555
# Mean Average Percentage Error: 0.6826791854622607
# Epoch 388:
# Avg training loss: 87770.464466
# Root Mean Squared Error: 1660.430722119603
# Mean Average Percentage Error: 0.597405758334895
# Epoch 389:
# Avg training loss: 85885.077209
# Root Mean Squared Error: 1746.3843658080398
# Mean Average Percentage Error: 0.5876240641718271
# Epoch 390:
# Avg training loss: 85676.594176
# Root Mean Squared Error: 1689.1303257985192
# Mean Average Percentage Error: 0.6808265715340345
# Epoch 391:
# Avg training loss: 84046.899754
# Root Mean Squared Error: 1768.475074259197
# Mean Average Percentage Error: 0.6224788703846229
# Epoch 392:
# Avg training loss: 81224.548532
# Root Mean Squared Error: 1713.9144786850748
# Mean Average Percentage Error: 0.617824720291376
# Epoch 393:
# Avg training loss: 80138.433643
# Root Mean Squared Error: 1775.4869644035623
# Mean Average Percentage Error: 0.634846520790006
# Epoch 394:
# Avg training loss: 80762.915596
# Root Mean Squared Error: 1687.5768777388898
# Mean Average Percentage Error: 0.6219243064119951
# Epoch 395:
# Avg training loss: 79853.882973
# Root Mean Squared Error: 1741.603853425776
# Mean Average Percentage Error: 0.62102034135256
# Epoch 396:
# Avg training loss: 76287.491173
# Root Mean Squared Error: 1766.211216222037
# Mean Average Percentage Error: 0.6216785458886385
# Epoch 397:
# Avg training loss: 74591.936398
# Root Mean Squared Error: 1790.4773254398967
# Mean Average Percentage Error: 0.6379594571638267
# Epoch 398:
# Avg training loss: 72784.221141
# Root Mean Squared Error: 1689.6279504071554
# Mean Average Percentage Error: 0.5964930564255639
# Epoch 399:
# Avg training loss: 72272.537104
# Root Mean Squared Error: 1771.292626907884
# Mean Average Percentage Error: 0.6679606689638097
# Epoch 400:
# Avg training loss: 72354.717191
# Root Mean Squared Error: 1779.8417791076915
# Mean Average Percentage Error: 0.6658488080696441
# Epoch 401:
# Avg training loss: 69128.758384
# Root Mean Squared Error: 1722.3820088224259
# Mean Average Percentage Error: 0.6319496180887874
# Epoch 402:
# Avg training loss: 68192.417028
# Root Mean Squared Error: 1771.553177346315
# Mean Average Percentage Error: 0.6453325851638892
# Epoch 403:
# Avg training loss: 67402.500892
# Root Mean Squared Error: 1780.9525804620143
# Mean Average Percentage Error: 0.6424974436988348
# Epoch 404:
# Avg training loss: 65496.903268
# Root Mean Squared Error: 1756.415484193001
# Mean Average Percentage Error: 0.6680005901640684
# Epoch 405:
# Avg training loss: 64846.697105
# Root Mean Squared Error: 1728.248523333501
# Mean Average Percentage Error: 0.6295540638911882
# Epoch 406:
# Avg training loss: 63670.727726
# Root Mean Squared Error: 1752.2701081289383
# Mean Average Percentage Error: 0.6380298849894352
# Epoch 407:
# Avg training loss: 63246.827794
# Root Mean Squared Error: 1795.2604668265267
# Mean Average Percentage Error: 0.654389346292417
# Epoch 408:
# Avg training loss: 60815.969652
# Root Mean Squared Error: 1794.6224017057991
# Mean Average Percentage Error: 0.6903990132322166
# Epoch 409:
# Avg training loss: 60019.148558
# Root Mean Squared Error: 1784.46018616404
# Mean Average Percentage Error: 0.649295652318385
# Epoch 410:
# Avg training loss: 59814.251027
# Root Mean Squared Error: 1802.9446292883986
# Mean Average Percentage Error: 0.670897435749269
# Epoch 411:
# Avg training loss: 57343.676073
# Root Mean Squared Error: 1762.42887166438
# Mean Average Percentage Error: 0.5964962951099394
# Epoch 412:
# Avg training loss: 56336.256880
# Root Mean Squared Error: 1766.8723465866965
# Mean Average Percentage Error: 0.6354785313480067
# Epoch 413:
# Avg training loss: 56096.785584
# Root Mean Squared Error: 1780.7871029034693
# Mean Average Percentage Error: 0.6317215948757
# Epoch 414:
# Avg training loss: 55516.024866
# Root Mean Squared Error: 1785.199173285322
# Mean Average Percentage Error: 0.6465682468601099
# Epoch 415:
# Avg training loss: 53215.951210
# Root Mean Squared Error: 1745.8423948775992
# Mean Average Percentage Error: 0.6178919486655107
# Epoch 416:
# Avg training loss: 52498.458811
# Root Mean Squared Error: 1818.84103932356
# Mean Average Percentage Error: 0.6765988995684394
# Epoch 417:
# Avg training loss: 52539.825463
# Root Mean Squared Error: 1773.0082719182476
# Mean Average Percentage Error: 0.6350285702911923
# Epoch 418:
# Avg training loss: 49895.239350
# Root Mean Squared Error: 1758.8965533680937
# Mean Average Percentage Error: 0.6131215909164199
# Epoch 419:
# Avg training loss: 49681.817734
# Root Mean Squared Error: 1781.3893218217634
# Mean Average Percentage Error: 0.6261096840954039
# Epoch 420:
# Avg training loss: 49077.718621
# Root Mean Squared Error: 1813.2279504424805
# Mean Average Percentage Error: 0.6606453627846989
# Epoch 421:
# Avg training loss: 47345.287262
# Root Mean Squared Error: 1828.4254522916524
# Mean Average Percentage Error: 0.6551150697580166
# Epoch 422:
# Avg training loss: 46744.014345
# Root Mean Squared Error: 1783.7946909530326
# Mean Average Percentage Error: 0.6708534270250114
# Epoch 423:
# Avg training loss: 45877.662280
# Root Mean Squared Error: 1786.458827415696
# Mean Average Percentage Error: 0.6154101093704987
# Epoch 424:
# Avg training loss: 45850.581188
# Root Mean Squared Error: 1767.112378134474
# Mean Average Percentage Error: 0.6537449165862361
# Epoch 425:
# Avg training loss: 44036.323380
# Root Mean Squared Error: 1838.5529063477213
# Mean Average Percentage Error: 0.6762957585222547
# Epoch 426:
# Avg training loss: 43630.703809
# Root Mean Squared Error: 1781.8562196394994
# Mean Average Percentage Error: 0.6242861395248009
# Epoch 427:
# Avg training loss: 42186.152662
# Root Mean Squared Error: 1824.1618871074227
# Mean Average Percentage Error: 0.6528635602907674
# Epoch 428:
# Avg training loss: 41010.430233
# Root Mean Squared Error: 1792.4006971360786
# Mean Average Percentage Error: 0.6789732306472988
# Epoch 429:
# Avg training loss: 41002.714878
# Root Mean Squared Error: 1823.290206093651
# Mean Average Percentage Error: 0.6492026178909404
# Epoch 430:
# Avg training loss: 39752.029674
# Root Mean Squared Error: 1775.7559195299175
# Mean Average Percentage Error: 0.6479603870993276
# Epoch 431:
# Avg training loss: 39152.076968
# Root Mean Squared Error: 1813.9806952384217
# Mean Average Percentage Error: 0.6908153142351157
# Epoch 432:
# Avg training loss: 38024.064990
# Root Mean Squared Error: 1803.7008237206546
# Mean Average Percentage Error: 0.6548444569042325
# Epoch 433:
# Avg training loss: 37621.524440
# Root Mean Squared Error: 1830.717768863769
# Mean Average Percentage Error: 0.7013872028679486
# Epoch 434:
# Avg training loss: 36702.510889
# Root Mean Squared Error: 1795.8740008729924
# Mean Average Percentage Error: 0.6164872516656139
# Epoch 435:
# Avg training loss: 36336.108210
# Root Mean Squared Error: 1872.2093713766592
# Mean Average Percentage Error: 0.7569712826513318
# Epoch 436:
# Avg training loss: 35263.075836
# Root Mean Squared Error: 1793.2762278260345
# Mean Average Percentage Error: 0.6600892094961206
# Epoch 437:
# Avg training loss: 34791.793097
# Root Mean Squared Error: 1818.5741700504598
# Mean Average Percentage Error: 0.7229614152788078
# Epoch 438:
# Avg training loss: 33964.606767
# Root Mean Squared Error: 1800.5301106361533
# Mean Average Percentage Error: 0.6445844853915896
# Epoch 439:
# Avg training loss: 33198.996421
# Root Mean Squared Error: 1766.3116065342158
# Avg training loss: 23705.414878
# Root Mean Squared Error: 1810.892532851834
# Mean Average Percentage Error: 0.6889902187912398
# Epoch 463:
# Avg training loss: 23256.303964
# Root Mean Squared Error: 1806.8533239182464
# Mean Average Percentage Error: 0.6897449761544087
# Epoch 464:
# Avg training loss: 22550.415847
# Root Mean Squared Error: 1875.0191233121507
# Mean Average Percentage Error: 0.7804347170803795
# Epoch 465:
# Avg training loss: 23070.769459
# Root Mean Squared Error: 1869.0983855245338
# Mean Average Percentage Error: 0.7575142479298766
# Epoch 466:
# Avg training loss: 22576.188999
# Root Mean Squared Error: 1859.6864572408979
# Mean Average Percentage Error: 0.7478465093525711
# Epoch 467:
# Avg training loss: 22798.984939
# Root Mean Squared Error: 1845.218286586784
# Mean Average Percentage Error: 0.7198679182700348
# Epoch 468:
# Avg training loss: 22295.555501
# Root Mean Squared Error: 1858.3554341975498
# Mean Average Percentage Error: 0.7666897099898917
# Epoch 469:
# Avg training loss: 22535.349073
# Root Mean Squared Error: 1857.7036457494216
# Mean Average Percentage Error: 0.7556695428463127
# Epoch 470:
# Avg training loss: 20661.270633
# Root Mean Squared Error: 1864.4636993639094
# Mean Average Percentage Error: 0.788936075364038
# Epoch 471:
# Avg training loss: 21770.846055
# Root Mean Squared Error: 1839.3513571651017
# Mean Average Percentage Error: 0.7384116106222873
# Epoch 472:
# Avg training loss: 21472.954968
# Root Mean Squared Error: 1868.7230898701557
# Mean Average Percentage Error: 0.801161755323455
# Epoch 473:
# Avg training loss: 20551.194858
# Root Mean Squared Error: 1920.5615408849542
# Mean Average Percentage Error: 0.8179072570307326
# Epoch 474:
# Avg training loss: 19875.162116
# Root Mean Squared Error: 1826.988858358485
# Mean Average Percentage Error: 0.7341403072959504
# Epoch 475:
# Avg training loss: 20083.926040
# Root Mean Squared Error: 1847.5982090622986
# Mean Average Percentage Error: 0.7607353704401968
# Epoch 476:
# Avg training loss: 19947.060567
# Root Mean Squared Error: 1854.091697022362
# Mean Average Percentage Error: 0.7532164868936608
# Epoch 477:
# Avg training loss: 19855.585806
# Root Mean Squared Error: 1874.2268081450566
# Mean Average Percentage Error: 0.8219151081725548
# Epoch 478:
# Avg training loss: 19211.366744
# Root Mean Squared Error: 1845.9969994491685
# Mean Average Percentage Error: 0.7840081287706859
# Epoch 479:
# Avg training loss: 19763.823370
# Root Mean Squared Error: 1864.4393091596698
# Mean Average Percentage Error: 0.7556187439949563
# Epoch 480:
# Avg training loss: 19144.641378
# Root Mean Squared Error: 1827.5858262419272
# Mean Average Percentage Error: 0.7527113732857305
# Epoch 481:
# Avg training loss: 20358.707027
# Root Mean Squared Error: 1845.2683499996429
# Mean Average Percentage Error: 0.7631265665983364
# Epoch 482:
# Avg training loss: 19585.519949
# Root Mean Squared Error: 1760.0627960551421
# Mean Average Percentage Error: 0.6573238487784703
# Epoch 483:
# Avg training loss: 19342.242168
# Root Mean Squared Error: 1831.8145862855517
# Mean Average Percentage Error: 0.6989544754265162
# Epoch 484:
# Avg training loss: 19490.684285
# Root Mean Squared Error: 1820.9388064007878
# Mean Average Percentage Error: 0.7463832542009803
# Epoch 485:
# Avg training loss: 18255.616276
# Root Mean Squared Error: 1830.0044593803475
# Mean Average Percentage Error: 0.6968604050323761
# Epoch 486:
# Avg training loss: 19305.316079
# Root Mean Squared Error: 1889.3322512300642
# Mean Average Percentage Error: 0.8043359744112415
# Epoch 487:
# Avg training loss: 19904.875926
# Root Mean Squared Error: 1848.4809526246643
# Mean Average Percentage Error: 0.7168285419719087
# Epoch 488:
# Avg training loss: 17855.482695
# Root Mean Squared Error: 1872.2975611431984
# Mean Average Percentage Error: 0.7962628087884757
# Epoch 489:
# Avg training loss: 18855.132573
# Root Mean Squared Error: 1845.2572535926474
# Mean Average Percentage Error: 0.7214590384156444
# Epoch 490:
# Avg training loss: 19654.643324
# Root Mean Squared Error: 1910.351589674659
# Mean Average Percentage Error: 0.8340913328584966
# Epoch 491:
# Avg training loss: 17514.371592
# Root Mean Squared Error: 1831.6318168024031
# Mean Average Percentage Error: 0.7343742379627964
# Epoch 492:
# Avg training loss: 18240.196093
# Root Mean Squared Error: 1863.4617739852124
# Mean Average Percentage Error: 0.7826345688692042
# Epoch 493:
# Avg training loss: 19011.693988
# Root Mean Squared Error: 1851.1334637656514
# Mean Average Percentage Error: 0.7759589296770326
# Epoch 494:
# Avg training loss: 17464.302722
# Root Mean Squared Error: 1816.4999005007116
# Mean Average Percentage Error: 0.6863037141089551
# Epoch 495:
# Avg training loss: 17773.667273
# Root Mean Squared Error: 1845.730671591076
# Mean Average Percentage Error: 0.7776427814167716
# Epoch 496:
# Avg training loss: 18244.634671
# Root Mean Squared Error: 1838.511079412421
# Mean Average Percentage Error: 0.7394539799848359
# Epoch 497:
# Avg training loss: 17027.102677
# Root Mean Squared Error: 1858.724287743318
# Mean Average Percentage Error: 0.751059067735214
# Epoch 498:
# Avg training loss: 18325.862657
# Root Mean Squared Error: 1865.120504656357
# Mean Average Percentage Error: 0.7495717653526344
# Epoch 499:
# Avg training loss: 18451.430713
# Root Mean Squared Error: 1883.3052115541216
# Mean Average Percentage Error: 0.7774476501451849
# Done!

# %%
# Save model state
model_path = os.path.join(os.getcwd(), 'model')
print(model_path)

torch.save(model.state_dict(), model_path + '\CNN_model_state.model')
# Out:
# C:\Users\paulr\GitHub\MSBD-5001-Group-Project\PR_Sandbox\model

# %%
# Load model state
model_path = os.path.join(os.getcwd(), 'model')
model.load_state_dict(torch.load(model_path + '\CNN_model_state.model'))
# Out:
# <All keys matched successfully>

# %%
print(train_loss_history)
# Out:
# [4024094.2056790865, 3959353.3735900517, 3890013.4985091533, 3818458.8504530326, 3743971.399041351, 3666836.559090699, 3587581.063699034, 3506762.5785567155, 3424829.091987181, 3342286.4632279268, 3259624.393011037, 3177373.890590092, 3095952.781308967, 3015796.1670603612, 2937367.296952356, 2861020.0351955625, 2787142.761004747, 2716011.8011842305, 2641735.0786986547, 2562882.5933059724, 2500567.2089055753, 2441696.3486812524, 2386692.684724817, 2334980.330487697, 2289220.0302944235, 2243887.042459072, 2203779.970880184, 2165798.8184802714, 2128869.318341498, 2093756.4192542296, 2069113.8395
# %%
# Plot Training Error
plt.plot(train_loss_history)
plt.title('Training Error vs. Training Epoch')
plt.ylabel('Training Error (MSE)')
plt.xlabel('Training Epoch')
plt.show()

# %%
# Plot training error, and testing results
fig, (ax1, ax2, ax3) = plt.subplots(3)
fig.set_figheight(10)
fig.set_figwidth(15)
fig.suptitle('Performance vs. Training Epoch')
ax1.plot(train_loss_history)
ax2.plot(test_history_RMSE)
ax3.plot(test_history_MAPE)
ax1.set(ylabel = 'Training Error (MSE)')
ax2.set(ylabel ='Testing Root Mean Squared Error')
ax3.set(ylabel ='Testing Mean Average Percentage Error', xlabel ='Training Epoch')
# Out:
# [Text(0, 0.5, 'Testing Mean Average Percentage Error'),
#  Text(0.5, 0, 'Training Epoch')]

# %%
# Now to make predictions and evaluate model
test_vals = test(test_dataloader, model)
print(f"Root Mean Squared Error: {math.sqrt(test_vals['Error_sq'].sum() / test_vals['Error_sq'].count())}")
print(f"Mean Average Percentage Error: {test_vals['Perc_Err'].mean()}")
# Out:
# Root Mean Squared Error: 1883.3052115541216
# Mean Average Percentage Error: 0.7774476501451849

# %%
test_vals
# Out:
#          Actual    Predicted        Error      Error_sq  Perc_Err
# 0   1400.199951   166.504562  1233.695389  1.522004e+06  0.881085
# 1    982.500000    77.415016   905.084984  8.191788e+05  0.921206
# 2   1336.699951   106.757553  1229.942398  1.512758e+06  0.920133
# 3    940.500000   116.654289   823.845711  6.787218e+05  0.875966
# 4   1168.900024    94.865028  1074.034996  1.153551e+06  0.918842
# 5    801.900024   316.350586   485.549438  2.357583e+05  0.605499
# 6    768.700012    26.524746   742.175266  5.508241e+05  0.965494
# 7   7117.200195   208.743118  6908.457077  4.772678e+07  0.970671
# 8   1595.400024    26.524746  1568.875278  2.461370e+06  0.983374
# 9   1830.300049   960.128418   870.171631  7.571987e+05  0.475426
# 10  1590.599976   217.985367  1372.614609  1.884071e+06  0.862954
# 11  1575.500000   145.284592  1430.215408  2.045516e+06  0.907785
# 12  1336.800049   524.743958   812.056091  6.594351e+05  0.607463
# 13  2140.600098  1013.752441  1126.847656  1.269786e+06  0.526417
# 14   359.899994    97.298775   262.601219  6.895940e+04  0.729651
# 15  1445.000000   257.525604  1187.474396  1.410095e+06  0.821782
# 16   551.299988   421.677490   129.622498  1.680199e+04  0.235122
# 17  1443.500000    40.871948  1402.628052  1.967365e+06  0.971686
# 18  1376.099976  1086.670166   289.429810  8.376961e+04  0.210326
# 19  1331.800049    26.972216  1304.827833  1.702576e+06  0.979748
# 20   538.000000   299.155548   238.844452  5.704667e+04  0.443949
# 21  3542.399902    65.721924  3476.677979  1.208729e+07  0.981447
# 22  1102.800049   149.261749   953.538300  9.092353e+05  0.864652
# 23  1930.500000    26.697376  1903.802624  3.624464e+06  0.986171
# 24  3007.399902   387.819580  2619.580322  6.862201e+06  0.871045
# 25   558.599976   169.955200   388.644775  1.510448e+05  0.695748
